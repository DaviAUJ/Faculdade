# %% [markdown]
# # Atividade Pontuada 03
#
# Aluno: Davi Araújo do Nascimento\
# Matrícula: 202300027801

# %% [markdown]
# import numpy as np
# from skimage.io import imread
# import matplotlib.pyplot as plt

# %% [markdown]
# ## Questão 01

# %%
digital_inteira = imread("digital.png")
plt.imshow(digital_inteira, cmap="grey")

# %%
digital_sd = digital_inteira[]
# Out:
# (238, 315)

# %%
def erosao(imagem: np.ndarray, elemento_estruturante: np.ndarray) -> np.ndarray:
    pass

# %%
def dilatacao(imagem: np.ndarray, elemento_estruturante: np.ndarray) -> np.ndarray:
    pass

# %%
def abertura(imagem: np.ndarray, elemento_estruturante: np.ndarray) -> np.ndarray:
    pass

# %%
def fechamento(imagem: np.ndarray, elemento_estruturante: np.ndarray) -> np.ndarray:
    pass

# %%
def hitOrMiss(imagem: np.ndarray, elemento_estruturante: np.ndarray) -> np.ndarray:
    pass

# %%
def afinamento(imagem: np.ndarray, elemento_estruturante: np.ndarray) -> np.ndarray:
    pass

# %%
def poda(imagem: np.ndarray, elemento_estruturante: np.ndarray) -> np.ndarray:
    pass
