# %%
import numpy as np
from skimage.io import imread
import matplotlib.pyplot as plt

# %%
konata = imread("konata.jpeg")

# %%
type(konata)
# Out:
# numpy.ndarray

# %%
konata.shape
# Out:
# (4096, 3072, 3)

# %%
plt.imshow(konata)

# %%
plt.imshow(konata, cmap="gray")

# %%
konata_gray = konata[:, :, 0]

# %%
plt.imshow(konata_gray, cmap='gray')

# %%
konata_gray.shape
# Out:
# (4096, 3072)

# %%
linha = konata_gray[600, :]

# %%
plt.plot(linha)

# %%
konata_bw = konata_gray.copy()

# %%
konata_bw[konata_bw > 127] = 255
plt.imshow(konata_bw, cmap="gray")

# %%
konata_bw[konata_bw < 255] = 0
plt.imshow(konata_bw, cmap="gray")

# %%
linha = konata_bw[600, :]
plt.plot(linha, "-k")
